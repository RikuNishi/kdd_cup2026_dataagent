# %%
import json
import numpy as np
import pandas as pd

# %%
with open('/Users/temmasaito/Work/IT/Competition/KDDCup2026/kdd_cup2026_dataagent/artifacts/public_input_context_summary.json', 'r', encoding='utf-8') as f:
    input_summary = json.load(f)

# %%
input_summary
# Out:
# {'task_count': 50,
#  'format_counts': {'csv': 40, 'json': 37, 'markdown': 64, 'sqlite': 27},
#  'tasks': [{'task_id': 'task_11',
#    'task_json': {'difficulty': 'easy',
#     'question': 'For patients with severe degree of thrombosis, list their ID, sex and disease the patient is diagnosed with.'},
#    'context': {'format_counts': {'json': 2, 'markdown': 1},
#     'files': [{'path': 'json/Examination.json',
#       'data_format': 'json',
#       'size_bytes': 253093,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'json/Patient.json',
#       'data_format': 'json',
#       'size_bytes': 249904,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5291,
#       'line_count': 103,
#       'preview': '# Knowledge Guide for Thrombosis Prediction Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "thrombosis_prediction" database, providing a unified understanding of the data structure, key entities, and business metrics. It is designed to ensure consistency, ac'}]}},
#   {'task_id': 'task_19',
#    'task_json': {'difficulty': 'easy',
#     'question': 'List the full name of the Student_Club members that grew up in Illinois state.'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/member.csv',
#       'data_format': 'csv',
#       'size_bytes': 3575,
#       'column_count': 9,
#       'columns': ['member_id',
#        'first_name',
#        'last_name',
#        'email',
#        'position',
#        't_shirt_size',
#        'phone',
#        'zip',
#        'link_to_major'],
#       'row_count': 33,
#       'sample_rows': [['rec1x5zBFIqoOuPW8',
#         'Angela',
#         'Sanders',
#         'angela.sanders@lpu.edu',
#         'Member',
#         'Medium',
#         '(651) 928-4507',
#         '55108',
#         'recxK3MHQFbR9J5uO']]},
#      {'path': 'json/zip_code.json',
#       'data_format': 'json',
#       'size_bytes': 7443215,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_22',
#    'task_json': {'difficulty': 'easy',
#     'question': 'State the date Connor Hilton paid his/her dues.'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/income.csv',
#       'data_format': 'csv',
#       'size_bytes': 2245,
#       'column_count': 6,
#       'columns': ['income_id',
#        'date_received',
#        'amount',
#        'source',
#        'notes',
#        'link_to_member'],
#       'row_count': 36,
#       'sample_rows': [['rec0s9ZrO15zhzUeE',
#         '2019-10-17',
#         '50',
#         'Dues',
#         '',
#         'reccW7q1KkhSKZsea']]},
#      {'path': 'json/member.json',
#       'data_format': 'json',
#       'size_bytes': 10135,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_24',
#    'task_json': {'difficulty': 'easy',
#     'question': 'How many members attended the "Women\'s Soccer" event?'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/attendance.csv',
#       'data_format': 'csv',
#       'size_bytes': 12092,
#       'column_count': 2,
#       'columns': ['link_to_event', 'link_to_member'],
#       'row_count': 326,
#       'sample_rows': [['rec2N69DMcrqN9PJC', 'recD078PnS3x2doBe']]},
#      {'path': 'json/event.json',
#       'data_format': 'json',
#       'size_bytes': 11197,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_25',
#    'task_json': {'difficulty': 'easy',
#     'question': 'Which event has the lowest cost?'},
#    'context': {'format_counts': {'csv': 1, 'json': 2, 'markdown': 1},
#     'files': [{'path': 'csv/budget.csv',
#       'data_format': 'csv',
#       'size_bytes': 3598,
#       'column_count': 7,
#       'columns': ['budget_id',
#        'category',
#        'spent',
#        'remaining',
#        'amount',
#        'event_status',
#        'link_to_event'],
#       'row_count': 52,
#       'sample_rows': [['rec0QmEc3cSQFQ6V2',
#         'Advertisement',
#         '67.81',
#         '7.19',
#         '75',
#         'Closed',
#         'recI43CzsZ0Q625ma']]},
#      {'path': 'json/event.json',
#       'data_format': 'json',
#       'size_bytes': 11197,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'json/expense.json',
#       'data_format': 'json',
#       'size_bytes': 8704,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_26',
#    'task_json': {'difficulty': 'easy',
#     'question': "How many members of the Student_Club have major in 'Physics Teaching'?"},
#    'context': {'format_counts': {'json': 2, 'markdown': 1},
#     'files': [{'path': 'json/major.json',
#       'data_format': 'json',
#       'size_bytes': 24152,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'json/member.json',
#       'data_format': 'json',
#       'size_bytes': 10135,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_27',
#    'task_json': {'difficulty': 'easy',
#     'question': 'List out the full name and total cost that member id "rec4BLdZHS2Blfp4v" incurred?'},
#    'context': {'format_counts': {'json': 2, 'markdown': 1},
#     'files': [{'path': 'json/expense.json',
#       'data_format': 'json',
#       'size_bytes': 8704,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'json/member.json',
#       'data_format': 'json',
#       'size_bytes': 10135,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_38',
#    'task_json': {'difficulty': 'easy',
#     'question': 'List all the withdrawals in cash transactions that the client with the id 3356 makes.'},
#    'context': {'format_counts': {'csv': 2, 'json': 2, 'markdown': 1},
#     'files': [{'path': 'csv/disp.csv',
#       'data_format': 'csv',
#       'size_bytes': 118970,
#       'column_count': 4,
#       'columns': ['disp_id', 'client_id', 'account_id', 'type'],
#       'row_count': 5369,
#       'sample_rows': [['1', '1', '1', 'OWNER']]},
#      {'path': 'csv/trans.csv',
#       'data_format': 'csv',
#       'size_bytes': 59775097,
#       'column_count': 10,
#       'columns': ['trans_id',
#        'account_id',
#        'date',
#        'type',
#        'operation',
#        'amount',
#        'balance',
#        'k_symbol',
#        'bank',
#        'account'],
#       'row_count': 1056320,
#       'sample_rows': [['1',
#         '1',
#         '1995-03-24',
#         'PRIJEM',
#         'VKLAD',
#         '1000',
#         '1000',
#         '',
#         '',
#         '']]},
#      {'path': 'json/account.json',
#       'data_format': 'json',
#       'size_bytes': 582852,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'json/client.json',
#       'data_format': 'json',
#       'size_bytes': 626351,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 4870,
#       'line_count': 69,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Financial Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the financial database, ensuring consistent understanding and usage of data across the organization. It emphasizes strict data governance standards, providi'}]}},
#   {'task_id': 'task_64',
#    'task_json': {'difficulty': 'easy',
#     'question': 'Please list all the superpowers of 3-D Man.'},
#    'context': {'format_counts': {'csv': 2, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/hero_power.csv',
#       'data_format': 'csv',
#       'size_bytes': 45546,
#       'column_count': 2,
#       'columns': ['hero_id', 'power_id'],
#       'row_count': 5825,
#       'sample_rows': [['1', '1']]},
#      {'path': 'csv/superpower.csv',
#       'data_format': 'csv',
#       'size_bytes': 3188,
#       'column_count': 2,
#       'columns': ['id', 'power_name'],
#       'row_count': 167,
#       'sample_rows': [['1', 'Agility']]},
#      {'path': 'json/superhero.json',
#       'data_format': 'json',
#       'size_bytes': 240215,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5603,
#       'line_count': 99,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Superhero\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "superhero" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data inte'}]}},
#   {'task_id': 'task_67',
#    'task_json': {'difficulty': 'easy',
#     'question': 'What is the average weight of all female superheroes?'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/superhero.csv',
#       'data_format': 'csv',
#       'size_bytes': 36279,
#       'column_count': 12,
#       'columns': ['id',
#        'superhero_name',
#        'full_name',
#        'gender_id',
#        'eye_colour_id',
#        'hair_colour_id',
#        'skin_colour_id',
#        'race_id',
#        'publisher_id',
#        'alignment_id',
#        'height_cm',
#        'weight_kg'],
#       'row_count': 750,
#       'sample_rows': [['1',
#         '3-D Man',
#         'Charles Chandler',
#         '1',
#         '9',
#         '13',
#         '1',
#         '1',
#         '13',
#         '1',
#         '188',
#         '90']]},
#      {'path': 'json/gender.json',
#       'data_format': 'json',
#       'size_bytes': 196,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5603,
#       'line_count': 99,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Superhero\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "superhero" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data inte'}]}},
#   {'task_id': 'task_74',
#    'task_json': {'difficulty': 'easy',
#     'question': 'Provide the eye colour of the superhero who has Karen Beecher-Duncan as their full name.'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/superhero.csv',
#       'data_format': 'csv',
#       'size_bytes': 36279,
#       'column_count': 12,
#       'columns': ['id',
#        'superhero_name',
#        'full_name',
#        'gender_id',
#        'eye_colour_id',
#        'hair_colour_id',
#        'skin_colour_id',
#        'race_id',
#        'publisher_id',
#        'alignment_id',
#        'height_cm',
#        'weight_kg'],
#       'row_count': 750,
#       'sample_rows': [['1',
#         '3-D Man',
#         'Charles Chandler',
#         '1',
#         '9',
#         '13',
#         '1',
#         '1',
#         '13',
#         '1',
#         '188',
#         '90']]},
#      {'path': 'json/colour.json',
#       'data_format': 'json',
#       'size_bytes': 1971,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5603,
#       'line_count': 99,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Superhero\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "superhero" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data inte'}]}},
#   {'task_id': 'task_75',
#    'task_json': {'difficulty': 'easy',
#     'question': 'What is the surname of the driver with the best lap time in race number 19 in the second qualifying period?'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/qualifying.csv',
#       'data_format': 'csv',
#       'size_bytes': 277359,
#       'column_count': 9,
#       'columns': ['qualifyId',
#        'raceId',
#        'driverId',
#        'constructorId',
#        'number',
#        'position',
#        'q1',
#        'q2',
#        'q3'],
#       'row_count': 7397,
#       'sample_rows': [['1',
#         '18',
#         '1',
#         '1',
#         '22',
#         '1',
#         '1:26.572',
#         '1:25.187',
#         '1:26.714']]},
#      {'path': 'json/drivers.json',
#       'data_format': 'json',
#       'size_bytes': 237752,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6067,
#       'line_count': 82,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Formula_1\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the Formula_1 database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data interp'}]}},
#   {'task_id': 'task_80',
#    'task_json': {'difficulty': 'easy',
#     'question': 'What is his number of the driver who finished 0:01:54 in the Q3 of qualifying race No.903?'},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/qualifying.csv',
#       'data_format': 'csv',
#       'size_bytes': 277359,
#       'column_count': 9,
#       'columns': ['qualifyId',
#        'raceId',
#        'driverId',
#        'constructorId',
#        'number',
#        'position',
#        'q1',
#        'q2',
#        'q3'],
#       'row_count': 7397,
#       'sample_rows': [['1',
#         '18',
#         '1',
#         '1',
#         '22',
#         '1',
#         '1:26.572',
#         '1:25.187',
#         '1:26.714']]},
#      {'path': 'json/drivers.json',
#       'data_format': 'json',
#       'size_bytes': 237752,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6067,
#       'line_count': 82,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Formula_1\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the Formula_1 database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data interp'}]}},
#   {'task_id': 'task_86',
#    'task_json': {'difficulty': 'easy',
#     'question': 'Which race was Alex Yoong in when he was in track number less than 20?'},
#    'context': {'format_counts': {'csv': 2, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/driverStandings.csv',
#       'data_format': 'csv',
#       'size_bytes': 827136,
#       'column_count': 7,
#       'columns': ['driverStandingsId',
#        'raceId',
#        'driverId',
#        'points',
#        'position',
#        'positionText',
#        'wins'],
#       'row_count': 31578,
#       'sample_rows': [['1', '18', '1', '10.0', '1', '1', '1']]},
#      {'path': 'csv/races.csv',
#       'data_format': 'csv',
#       'size_bytes': 100343,
#       'column_count': 8,
#       'columns': ['raceId',
#        'year',
#        'round',
#        'circuitId',
#        'name',
#        'date',
#        'time',
#        'url'],
#       'row_count': 976,
#       'sample_rows': [['1',
#         '2009',
#         '1',
#         '1',
#         'Australian Grand Prix',
#         '2009-03-29',
#         '06:00:00',
#         'http://en.wikipedia.org/wiki/2009_Australian_Grand_Prix']]},
#      {'path': 'json/drivers.json',
#       'data_format': 'json',
#       'size_bytes': 237752,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6067,
#       'line_count': 82,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Formula_1\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the Formula_1 database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data interp'}]}},
#   {'task_id': 'task_89',
#    'task_json': {'difficulty': 'easy',
#     'question': "What's the finish time for the driver who ranked second in 2008's Chinese Grand Prix?"},
#    'context': {'format_counts': {'csv': 1, 'json': 1, 'markdown': 1},
#     'files': [{'path': 'csv/results.csv',
#       'data_format': 'csv',
#       'size_bytes': 1229092,
#       'column_count': 18,
#       'columns': ['resultId',
#        'raceId',
#        'driverId',
#        'constructorId',
#        'number',
#        'grid',
#        'position',
#        'positionText',
#        'positionOrder',
#        'points',
#        'laps',
#        'time',
#        'milliseconds',
#        'fastestLap',
#        'rank',
#        'fastestLapTime',
#        'fastestLapSpeed',
#        'statusId'],
#       'row_count': 23657,
#       'sample_rows': [['1',
#         '18',
#         '1',
#         '1',
#         '22',
#         '1',
#         '1',
#         '1',
#         '1',
#         '10.0',
#         '58',
#         '1:34:50.616',
#         '5690616',
#         '39',
#         '2',
#         '1:27.452',
#         '218.300',
#         '1']]},
#      {'path': 'json/races.json',
#       'data_format': 'json',
#       'size_bytes': 244294,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6067,
#       'line_count': 82,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Formula_1\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the Formula_1 database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent data interp'}]}},
#   {'task_id': 'task_145',
#    'task_json': {'difficulty': 'medium',
#     'question': 'Among the events attended by more than 10 members of the Student_Club, how many of them are meetings?'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/attendance.csv',
#       'data_format': 'csv',
#       'size_bytes': 12092,
#       'column_count': 2,
#       'columns': ['link_to_event', 'link_to_member'],
#       'row_count': 326,
#       'sample_rows': [['rec2N69DMcrqN9PJC', 'recD078PnS3x2doBe']]},
#      {'path': 'db/event.db',
#       'data_format': 'sqlite',
#       'size_bytes': 20480,
#       'table_count': 1,
#       'tables': [{'name': 'event',
#         'column_count': 7,
#         'columns': [{'name': 'event_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': True},
#          {'name': 'event_name',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'event_date',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'type',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'notes',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'location',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'status',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 42,
#         'create_sql': 'CREATE TABLE event\n(\n    event_id   TEXT\n        constraint event_pk\n            primary key,\n    event_name TEXT,\n    event_date TEXT,\n    type       TEXT,\n    notes      TEXT,\n    location   TEXT,\n    status     TEXT\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_163',
#    'task_json': {'difficulty': 'medium',
#     'question': "Identify the type of expenses and their total value approved for 'October Meeting' event."},
#    'context': {'format_counts': {'csv': 1,
#      'json': 1,
#      'markdown': 1,
#      'sqlite': 1},
#     'files': [{'path': 'csv/expense.csv',
#       'data_format': 'csv',
#       'size_bytes': 2980,
#       'column_count': 7,
#       'columns': ['expense_id',
#        'expense_description',
#        'expense_date',
#        'cost',
#        'approved',
#        'link_to_member',
#        'link_to_budget'],
#       'row_count': 32,
#       'sample_rows': [['rec017x6R3hQqkLAo',
#         'Post Cards, Posters',
#         '2019-08-20',
#         '122.06',
#         'true',
#         'rec4BLdZHS2Blfp4v',
#         'recvKTAWAFKkVNnXQ']]},
#      {'path': 'db/event.db',
#       'data_format': 'sqlite',
#       'size_bytes': 20480,
#       'table_count': 1,
#       'tables': [{'name': 'event',
#         'column_count': 7,
#         'columns': [{'name': 'event_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': True},
#          {'name': 'event_name',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'event_date',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'type',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'notes',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'location',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'status',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 42,
#         'create_sql': 'CREATE TABLE event\n(\n    event_id   TEXT\n        constraint event_pk\n            primary key,\n    event_name TEXT,\n    event_date TEXT,\n    type       TEXT,\n    notes      TEXT,\n    location   TEXT,\n    status     TEXT\n)'}]},
#      {'path': 'json/budget.json',
#       'data_format': 'json',
#       'size_bytes': 11786,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5459,
#       'line_count': 90,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: student_club\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `student_club` database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistent dat'}]}},
#   {'task_id': 'task_169',
#    'task_json': {'difficulty': 'medium',
#     'question': 'What was the average monthly consumption of customers in SME for the year 2013?'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/yearmonth.csv',
#       'data_format': 'csv',
#       'size_bytes': 8210334,
#       'column_count': 3,
#       'columns': ['CustomerID', 'Date', 'Consumption'],
#       'row_count': 383282,
#       'sample_rows': [['5', '201207', '528.3']]},
#      {'path': 'db/customers.db',
#       'data_format': 'sqlite',
#       'size_bytes': 929792,
#       'table_count': 1,
#       'tables': [{'name': 'customers',
#         'column_count': 3,
#         'columns': [{'name': 'CustomerID',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'Segment',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Currency',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 32461,
#         'create_sql': 'CREATE TABLE customers\n(\n    CustomerID INTEGER UNIQUE     not null\n        primary key,\n    Segment    TEXT null,\n    Currency   TEXT null\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 4795,
#       'line_count': 94,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Debit Card Specializing\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "Debit Card Specializing" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to'}]}},
#   {'task_id': 'task_173',
#    'task_json': {'difficulty': 'medium',
#     'question': 'Please list the countries of the gas stations with transactions taken place in June, 2013.'},
#    'context': {'format_counts': {'csv': 1,
#      'json': 1,
#      'markdown': 1,
#      'sqlite': 1},
#     'files': [{'path': 'csv/yearmonth.csv',
#       'data_format': 'csv',
#       'size_bytes': 8210334,
#       'column_count': 3,
#       'columns': ['CustomerID', 'Date', 'Consumption'],
#       'row_count': 383282,
#       'sample_rows': [['5', '201207', '528.3']]},
#      {'path': 'db/transactions_1k.db',
#       'data_format': 'sqlite',
#       'size_bytes': 65536,
#       'table_count': 1,
#       'tables': [{'name': 'transactions_1k',
#         'column_count': 9,
#         'columns': [{'name': 'TransactionID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': True},
#          {'name': 'Date',
#           'type': 'DATE',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Time',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'CustomerID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'CardID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'GasStationID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'ProductID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Amount',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Price',
#           'type': 'REAL',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 1000,
#         'create_sql': 'CREATE TABLE "transactions_1k"\n(\n    TransactionID INTEGER\n        primary key autoincrement,\n    Date          DATE,\n    Time          TEXT,\n    CustomerID    INTEGER,\n    CardID        INTEGER,\n    GasStationID  INTEGER,\n    ProductID     INTEGER,\n    Amount        INTEGER,\n    Price         REAL\n)'}]},
#      {'path': 'json/gasstations.json',
#       'data_format': 'json',
#       'size_bytes': 641302,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 4795,
#       'line_count': 94,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Debit Card Specializing\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "Debit Card Specializing" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to'}]}},
#   {'task_id': 'task_180',
#    'task_json': {'difficulty': 'medium',
#     'question': 'For all the people who paid more than 29.00 per unit of product id No.5. Give their consumption status in the August of 2012.'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/yearmonth.csv',
#       'data_format': 'csv',
#       'size_bytes': 8210334,
#       'column_count': 3,
#       'columns': ['CustomerID', 'Date', 'Consumption'],
#       'row_count': 383282,
#       'sample_rows': [['5', '201207', '528.3']]},
#      {'path': 'db/transactions_1k.db',
#       'data_format': 'sqlite',
#       'size_bytes': 65536,
#       'table_count': 1,
#       'tables': [{'name': 'transactions_1k',
#         'column_count': 9,
#         'columns': [{'name': 'TransactionID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': True},
#          {'name': 'Date',
#           'type': 'DATE',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Time',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'CustomerID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'CardID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'GasStationID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'ProductID',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Amount',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'Price',
#           'type': 'REAL',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 1000,
#         'create_sql': 'CREATE TABLE "transactions_1k"\n(\n    TransactionID INTEGER\n        primary key autoincrement,\n    Date          DATE,\n    Time          TEXT,\n    CustomerID    INTEGER,\n    CardID        INTEGER,\n    GasStationID  INTEGER,\n    ProductID     INTEGER,\n    Amount        INTEGER,\n    Price         REAL\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 4795,
#       'line_count': 94,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: Debit Card Specializing\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "Debit Card Specializing" database, providing authoritative definitions, metric formulations, and governance standards. It is designed to'}]}},
#   {'task_id': 'task_194',
#    'task_json': {'difficulty': 'medium',
#     'question': 'What are the bonds that have phosphorus and nitrogen as their atom elements?'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/connected.csv',
#       'data_format': 'csv',
#       'size_bytes': 725208,
#       'column_count': 3,
#       'columns': ['atom_id', 'atom_id2', 'bond_id'],
#       'row_count': 24758,
#       'sample_rows': [['TR000_1', 'TR000_2', 'TR000_1_2']]},
#      {'path': 'db/atom.db',
#       'data_format': 'sqlite',
#       'size_bytes': 1384448,
#       'table_count': 2,
#       'tables': [{'name': 'atom',
#         'column_count': 3,
#         'columns': [{'name': 'atom_id',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'molecule_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False},
#          {'name': 'element',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False}],
#         'row_count': 12333,
#         'create_sql': 'CREATE TABLE `atom` (\n  `atom_id` TEXT NOT NULL,\n  `molecule_id` TEXT DEFAULT NULL,\n  `element` TEXT DEFAULT NULL,\n  PRIMARY KEY (`atom_id`),\n  FOREIGN KEY (`molecule_id`) REFERENCES `molecule` (`molecule_id`)\n)'},
#        {'name': 'connected',
#         'column_count': 3,
#         'columns': [{'name': 'atom_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'atom_id2',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'bond_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 24758,
#         'create_sql': 'CREATE TABLE "connected" (\n"atom_id" TEXT,\n  "atom_id2" TEXT,\n  "bond_id" TEXT\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6616,
#       'line_count': 93,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Toxicology Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the toxicology database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistency, accuracy'}]}},
#   {'task_id': 'task_196',
#    'task_json': {'difficulty': 'medium',
#     'question': 'What is the average number of bonds the atoms with the element iodine have?'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/connected.csv',
#       'data_format': 'csv',
#       'size_bytes': 725208,
#       'column_count': 3,
#       'columns': ['atom_id', 'atom_id2', 'bond_id'],
#       'row_count': 24758,
#       'sample_rows': [['TR000_1', 'TR000_2', 'TR000_1_2']]},
#      {'path': 'db/atom.db',
#       'data_format': 'sqlite',
#       'size_bytes': 516096,
#       'table_count': 1,
#       'tables': [{'name': 'atom',
#         'column_count': 3,
#         'columns': [{'name': 'atom_id',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'molecule_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False},
#          {'name': 'element',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False}],
#         'row_count': 12333,
#         'create_sql': 'CREATE TABLE `atom` (\n  `atom_id` TEXT NOT NULL,\n  `molecule_id` TEXT DEFAULT NULL,\n  `element` TEXT DEFAULT NULL,\n  PRIMARY KEY (`atom_id`),\n  FOREIGN KEY (`molecule_id`) REFERENCES `molecule` (`molecule_id`)\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6616,
#       'line_count': 93,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Toxicology Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the toxicology database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistency, accuracy'}]}},
#   {'task_id': 'task_199',
#    'task_json': {'difficulty': 'medium',
#     'question': 'List the names and funding types of schools from Riverside-related school districts where the average SAT math score across schools exceeds 400.'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/frpm.csv',
#       'data_format': 'csv',
#       'size_bytes': 2836512,
#       'column_count': 29,
#       'columns': ['CDSCode',
#        'Academic Year',
#        'County Code',
#        'District Code',
#        'School Code',
#        'County Name',
#        'District Name',
#        'School Name',
#        'District Type',
#        'School Type',
#        'Educational Option Type',
#        'NSLP Provision Status',
#        'Charter School (Y/N)',
#        'Charter School Number',
#        'Charter Funding Type',
#        'IRC',
#        'Low Grade',
#        'High Grade',
#        'Enrollment (K-12)',
#        'Free Meal Count (K-12)',
#        'Percent (%) Eligible Free (K-12)',
#        'FRPM Count (K-12)',
#        'Percent (%) Eligible FRPM (K-12)',
#        'Enrollment (Ages 5-17)',
#        'Free Meal Count (Ages 5-17)',
#        'Percent (%) Eligible Free (Ages 5-17)',
#        'FRPM Count (Ages 5-17)',
#        'Percent (%) Eligible FRPM (Ages 5-17)',
#        '2013-14 CALPADS Fall 1 Certification Status'],
#       'row_count': 9986,
#       'sample_rows': [['01100170109835',
#         '2014-2015',
#         '01',
#         '10017',
#         '0109835',
#         'Alameda',
#         'Alameda County Office of Education',
#         'FAME Public Charter',
#         'County Office of Education (COE)',
#         'K-12 Schools (Public)',
#         'Traditional',
#         '',
#         '1',
#         '0728',
#         'Directly funded',
#         '1',
#         'K',
#         '12',
#         '1087.0',
#         '565.0',
#         '0.519779208831647',
#         '715.0',
#         '0.657773689052438',
#         '1070.0',
#         '553.0',
#         '0.516822429906542',
#         '702.0',
#         '0.65607476635514',
#         '1']]},
#      {'path': 'db/satscores.db',
#       'data_format': 'sqlite',
#       'size_bytes': 266240,
#       'table_count': 1,
#       'tables': [{'name': 'satscores',
#         'column_count': 11,
#         'columns': [{'name': 'cds',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'rtype',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': False},
#          {'name': 'sname',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'dname',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'cname',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'enroll12',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': None,
#           'primary_key': False},
#          {'name': 'NumTstTakr',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': None,
#           'primary_key': False},
#          {'name': 'AvgScrRead',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'AvgScrMath',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'AvgScrWrite',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'NumGE1500',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 2269,
#         'create_sql': 'CREATE TABLE satscores\n(\n    cds         TEXT not null\n        primary key,\n    rtype       TEXT  not null,\n    sname       TEXT null,\n    dname       TEXT null,\n    cname       TEXT null,\n    enroll12    INTEGER         not null,\n    NumTstTakr  INTEGER          not null,\n    AvgScrRead  INTEGER          null,\n    AvgScrMath  INTEGER          null,\n    AvgScrWrite INTEGER          null,\n    NumGE1500   INTEGER          null,\n--     PctGE1500   double      null,\n        foreign key (cds) references schools (CDSCode)\n)'}]},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5138,
#       'line_count': 89,
#       'preview': '# Knowledge Guide for California Schools Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `california_schools` database, providing a unified understanding of its structure, key entities, and business metrics. It is designed to support enterprise-level data gov'}]}},
#   {'task_id': 'task_200',
#    'task_json': {'difficulty': 'medium',
#     'question': 'Calculate the total atoms with triple-bond molecules containing the element phosphorus or bromine.'},
#    'context': {'format_counts': {'csv': 1,
#      'json': 1,
#      'markdown': 1,
#      'sqlite': 1},
#     'files': [{'path': 'csv/atom.csv',
#       'data_format': 'csv',
#       'size_bytes': 218746,
#       'column_count': 3,
#       'columns': ['atom_id', 'molecule_id', 'element'],
#       'row_count': 12333,
#       'sample_rows': [['TR000_1', 'TR000', 'cl']]},
#      {'path': 'db/bond.db',
#       'data_format': 'sqlite',
#       'size_bytes': 581632,
#       'table_count': 1,
#       'tables': [{'name': 'bond',
#         'column_count': 3,
#         'columns': [{'name': 'bond_id',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'molecule_id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False},
#          {'name': 'bond_type',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': 'NULL',
#           'primary_key': False}],
#         'row_count': 12379,
#         'create_sql': 'CREATE TABLE `bond` (\n  `bond_id` TEXT NOT NULL,\n  `molecule_id` TEXT DEFAULT NULL,\n  `bond_type` TEXT DEFAULT NULL,\n  PRIMARY KEY (`bond_id`),\n  FOREIGN KEY (`molecule_id`) REFERENCES `molecule` (`molecule_id`)\n)'}]},
#      {'path': 'json/molecule.json',
#       'data_format': 'json',
#       'size_bytes': 21310,
#       'fully_loaded': True,
#       'top_level_keys': ['table', 'records']},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 6616,
#       'line_count': 93,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Toxicology Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the toxicology database, providing authoritative definitions, metric formulations, and governance standards. It is designed to ensure consistency, accuracy'}]}},
#   {'task_id': 'task_214',
#    'task_json': {'difficulty': 'medium',
#     'question': 'How many Brazilian Portuguese translated sets are inside the Commander block?'},
#    'context': {'format_counts': {'csv': 1, 'markdown': 1, 'sqlite': 1},
#     'files': [{'path': 'csv/set_translations.csv',
#       'data_format': 'csv',
#       'size_bytes': 43847,
#       'column_count': 4,
#       'columns': ['id', 'language', 'setCode', 'translation'],
#       'row_count': 1210,
#       'sample_rows': [['1', 'Chinese Simplified', '10E', '核心系列第十版']]},
#      {'path': 'db/sets.db',
#       'data_format': 'sqlite',
#       'size_bytes': 110592,
#       'table_count': 1,
#       'tables': [{'name': 'sets',
#         'column_count': 21,
#         'columns': [{'name': 'id',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'baseSetSize',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'block',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'booster',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'code',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': False},
#          {'name': 'isFoilOnly',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isForeignOnly',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isNonFoilOnly',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isOnlineOnly',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isPartialPreview',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'keyruneCode',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mcmId',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mcmIdExtras',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mcmName',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mtgoCode',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'name',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'parentCode',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'releaseDate',
#           'type': 'DATE',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'tcgplayerGroupId',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'totalSetSize',
#           'type': 'INTEGER',
#           'not_null': False,
# ...
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5291,
#       'line_count': 103,
#       'preview': '# Knowledge Guide for Thrombosis Prediction Database\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the "thrombosis_prediction" database, providing a unified understanding of the data structure, key entities, and business metrics. It is designed to ensure consistency, ac'}]}},
#   {'task_id': 'task_420',
#    'task_json': {'difficulty': 'hard',
#     'question': 'What percentage of cards with format commander and legal status do not have a content warning?'},
#    'context': {'format_counts': {'markdown': 2, 'sqlite': 1},
#     'files': [{'path': 'db/cards.db',
#       'data_format': 'sqlite',
#       'size_bytes': 61579264,
#       'table_count': 1,
#       'tables': [{'name': 'cards',
#         'column_count': 74,
#         'columns': [{'name': 'id',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': None,
#           'primary_key': True},
#          {'name': 'artist',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'asciiName',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'availability',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'borderColor',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'cardKingdomFoilId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'cardKingdomId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'colorIdentity',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'colorIndicator',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'colors',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'convertedManaCost',
#           'type': 'REAL',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'duelDeck',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'edhrecRank',
#           'type': 'INTEGER',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'faceConvertedManaCost',
#           'type': 'REAL',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'faceName',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'flavorName',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'flavorText',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'frameEffects',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'frameVersion',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'hand',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'hasAlternativeDeckLimit',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'hasContentWarning',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'hasFoil',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'hasNonFoil',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isAlternative',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isFullArt',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isOnlineOnly',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isOversized',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isPromo',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isReprint',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isReserved',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isStarter',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isStorySpotlight',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isTextless',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'isTimeshifted',
#           'type': 'INTEGER',
#           'not_null': True,
#           'default': '0',
#           'primary_key': False},
#          {'name': 'keywords',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'layout',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'leadershipSkills',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'life',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'loyalty',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'manaCost',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mcmId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mcmMetaId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mtgArenaId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mtgjsonV4Id',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mtgoFoilId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'mtgoId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'multiverseId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'name',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'number',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'originalReleaseDate',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'originalText',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'originalType',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'otherFaceIds',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'power',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'printings',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'promoTypes',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'purchaseUrls',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'rarity',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'scryfallId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'scryfallIllustrationId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'scryfallOracleId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'setCode',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'side',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'subtypes',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'supertypes',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'tcgplayerProductId',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'text',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'toughness',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'type',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'types',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'uuid',
#           'type': 'TEXT',
#           'not_null': True,
#           'default': None,
#           'primary_key': False},
#          {'name': 'variations',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False},
#          {'name': 'watermark',
#           'type': 'TEXT',
#           'not_null': False,
#           'default': None,
#           'primary_key': False}],
#         'row_count': 56822,
#         'create_sql': 'CREATE TABLE "cards"\n(\n    id                      INTEGER           not null\n        primary key autoincrement,\n    artist                  TEXT,\n    asciiName               TEXT,\n    availability            TEXT,\n    borderColor             TEXT,\n    cardKingdomFoilId       TEXT,\n    cardKingdomId           TEXT,\n    colorIdentity           TEXT,\n    colorIndicator          TEXT,\n    colors                  TEXT,\n    convertedManaCost       REAL,\n    duelDeck                TEXT,\n    edhrecRank              INTEGER,\n    faceConvertedManaCost   REAL,\n    faceName                TEXT,\n    flavorName              TEXT,\n    flavorText              TEXT,\n    frameEffects            TEXT,\n    frameVersion            TEXT,\n    hand                    TEXT,\n    hasAlternativeDeckLimit INTEGER default 0 not null,\n    hasContentWarning       INTEGER default 0 not null,\n    hasFoil                 INTEGER default 0 not null,\n    hasNonFoil              INTEGER default 0 not null,\n    isAlternative           INTEGER default 0 not null,\n    isFullArt               INTEGER default 0 not null,\n    isOnlineOnly            INTEGER default 0 not null,\n    isOversized             INTEGER default 0 not null,\n    isPromo                 INTEGER default 0 not null,\n    isReprint               INTEGER default 0 not null,\n    isReserved              INTEGER default 0 not null,\n    isStarter               INTEGER default 0 not null,\n    isStorySpotlight        INTEGER default 0 not null,\n    isTextless              INTEGER default 0 not null,\n    isTimeshifted           INTEGER default 0 not null,\n    keywords                TEXT,\n    layout                  TEXT,\n    leadershipSkills        TEXT,\n    life                    TEXT,\n    loyalty                 TEXT,\n    manaCost                TEXT,\n    mcmId                   TEXT,\n    mcmMetaId               TEXT,\n    mtgArenaId              TEXT,\n    mtgjsonV4Id             TEXT,\n    mtgoFoilId              TEXT,\n    mtgoId                  TEXT,\n    multiverseId            TEXT,\n    name                    TEXT,\n    number                  TEXT,\n    originalReleaseDate     TEXT,\n    originalText            TEXT,\n    originalType            TEXT,\n    otherFaceIds            TEXT,\n    power                   TEXT,\n    printings               TEXT,\n    promoTypes              TEXT,\n    purchaseUrls            TEXT,\n    rarity                  TEXT,\n    scryfallId              TEXT,\n    scryfallIllustrationId  TEXT,\n    scryfallOracleId        TEXT,\n    setCode                 TEXT,\n    side                    TEXT,\n    subtypes                TEXT,\n    supertypes              TEXT,\n    tcgplayerProductId      TEXT,\n    text                    TEXT,\n    toughness               TEXT,\n    type                    TEXT,\n    types                   TEXT,\n    uuid                    TEXT              not null\n        unique,\n    variations              TEXT,\n    watermark               TEXT\n)'}]},
#      {'path': 'doc/legalities.md',
#       'data_format': 'markdown',
#       'size_bytes': 56877,
#       'line_count': 443,
#       'preview': '### Portfolio of Sanctioned Assets: A Legality Compendium\n\nThis document provides a detailed audit of the sanctioned strategic units within the current competitive framework. Each entry represents a specific legality ruling, linking a portfolio asset to its corresponding card identifier. The followi'},
#      {'path': 'knowledge.md',
#       'data_format': 'markdown',
#       'size_bytes': 5350,
#       'line_count': 98,
#       'preview': '# Enterprise Data Governance Knowledge Guide for Database: card_games\n\n## 1. Introduction\nThis guide serves as a comprehensive semantic layer for the `card_games` database, providing a unified understanding of its structure, key entities, and business metrics. It is designed to ensure data governanc'}]}}]}
